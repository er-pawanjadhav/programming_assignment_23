# %%
a = input("enter no : ")
a = a.split(',')
def multiply_nums(a):
    d = []
    for i in a:
         if i != ' ':
                i = int(i)
                d.append(i)
    m = 1
    for i in d:
        m=m*i
    return m

print(multiply_nums(a))
# Out:
# enter no : 10,-2
# [10, -2]
# -20
