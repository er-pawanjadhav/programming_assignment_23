# %%
def square_digits(a):
    s = ''
    for i in a:
        i = int(i)
        i = i**2
        s = s+str(i)
    s =int(s)
    return s

a=int(input("enter a no : "))
a = list(str(a))
print(square_digits(a))
# Out:
# enter a no : 9119
# 811181
