# %%
def is_symmetric(a):
    b = ''
    for i in a:
        b = i+b
    if a==b:
        return True
    else:
        return False
a = input("enter a no:")
print(is_symmetric(a))
# Out:
# enter a no:575
# True
